# %%
import json

# %%
tgt_dir = dict()

# %%
with open('sort_info_new.txt') as f:
    sin_list = f.readlines()

# %%
map_531 = dict([item.strip().split(' -> ') for item in sin_list if item])

# %%
map_531 = {k: int(v)-1 for k, v in map_531.items()}

# %%
map_531
# Out:
# {'Albert Einstein/C00020.obj': 0,
#  'Angela Merkel/C00024.obj': 1,
#  'Angelina Jolie/C00011.obj': 2,
#  'Ann Hathaway/C00020.obj': 3,
#  'Ann Hathaway/C00022.obj': 4,
#  'Anthony Hopkins/C00026.obj': 5,
#  'Anthony Hopkins/C00001.obj': 6,
#  'Arnold Schwarzenegger/C00008.obj': 7,
#  'Arnold Schwarzenegger/C00007.obj': 8,
#  'Arnold Schwarzenegger/C00015.obj': 9,
#  'Arsene Wenger/C00002.obj': 10,
#  'Ashton Kutcher/C00004.obj': 11,
#  'Ban Ki moon/C00008.obj': 12,
#  'Barack Obama/C00040.obj': 13,
#  'Barack Obama/C00018.obj': 14,
#  'Barack Obama/C00001.obj': 15,
#  'Barack Obama/C00037.obj': 16,
#  'Ben Stiller/C00006.obj': 17,
#  'Ben Stiller/C00015.obj': 18,
#  'Ben Stiller/C00012.obj': 19,
#  'Benedict Cumberbatch/C00009.obj': 20,
#  'Benedict Cumberbatch/C00024.obj': 21,
#  'Benedict Cumberbatch/C00001.obj': 22,
#  'Benedict Cumberbatch/C00002.obj': 23,
#  'Bill Murray/C00006.obj': 24,
#  'Bill Murray/C00021.obj': 25,
#  'Bill Murray/C00041.obj': 26,
# ...

# %%
with open('sort_info.txt') as f:
    si_list = f.readlines()

# %%
map_1268 = [item.strip().split(' -> ') for item in si_list if item]

# %%
map_1268 = {k.strip(): int(v)-1 for k, v in map_1268}

# %%
map_1268
# Out:
# {'Abraham Lincoln/C00024.obj': 0,
#  'Albert Einstein/C00014.obj': 1,
#  'Albert Einstein/C00020.obj': 2,
#  'Albert Einstein/C00023.obj': 3,
#  'Angela Merkel/C00024.obj': 4,
#  'Angela Merkel/C00039.obj': 5,
#  'Angela Merkel/C00054.obj': 6,
#  'Angela Merkel/C00065.obj': 7,
#  'Angelina Jolie/C00011.obj': 8,
#  'Ann Hathaway/C00007.obj': 9,
#  'Ann Hathaway/C00012.obj': 10,
#  'Ann Hathaway/C00019.obj': 11,
#  'Ann Hathaway/C00020.obj': 12,
#  'Ann Hathaway/C00022.obj': 13,
#  'Ann Hathaway/C00023.obj': 14,
#  'Anthony Hopkins/C00001.obj': 15,
#  'Anthony Hopkins/C00005.obj': 16,
#  'Anthony Hopkins/C00026.obj': 17,
#  'Arnold Schwarzenegger/C00007.obj': 18,
#  'Arnold Schwarzenegger/C00008.obj': 19,
#  'Arnold Schwarzenegger/C00015.obj': 20,
#  'Arnold Schwarzenegger/C00039.obj': 21,
#  'Arsene Wenger/C00001.obj': 22,
#  'Arsene Wenger/C00002.obj': 23,
#  'Arsene Wenger/C00007.obj': 24,
#  'Arsene Wenger/C00014.obj': 25,
#  'Arsene Wenger/C00015.obj': 26,
# ...

# %%
tgt_map = dict()

# %%
for k, v in map_531.items():
    tgt_map[map_1268[k]] = v

# %%
tgt_map
# Out:
# {2: 0,
#  4: 1,
#  8: 2,
#  12: 3,
#  13: 4,
#  17: 5,
#  15: 6,
#  19: 7,
#  18: 8,
#  20: 9,
#  23: 10,
#  29: 11,
#  37: 12,
#  49: 13,
#  44: 14,
#  38: 15,
#  48: 16,
#  51: 17,
#  54: 18,
#  53: 19,
#  58: 20,
#  63: 21,
#  55: 22,
#  56: 23,
#  71: 24,
#  73: 25,
#  77: 26,
#  84: 27,
#  90: 28,
#  87: 29,
#  93: 30,
#  94: 31,
#  99: 32,
#  100: 33,
#  102: 34,
#  114: 35,
#  117: 36,
#  128: 37,
#  126: 38,
#  130: 39,
#  125: 40,
#  124: 41,
#  129: 42,
#  139: 43,
#  135: 44,
#  132: 45,
#  136: 46,
#  140: 47,
#  142: 48,
#  143: 49,
#  148: 50,
#  152: 51,
#  151: 52,
#  159: 53,
#  160: 54,
#  163: 55,
#  172: 56,
#  170: 57,
#  166: 58,
#  186: 59,
#  187: 60,
#  193: 61,
#  190: 62,
#  198: 63,
#  203: 64,
#  208: 65,
#  204: 66,
#  206: 67,
#  219: 68,
#  234: 69,
#  230: 70,
#  228: 71,
#  233: 72,
#  227: 73,
#  245: 74,
#  236: 75,
#  242: 76,
#  251: 77,
#  248: 78,
#  252: 79,
#  255: 80,
#  256: 81,
#  257: 82,
#  260: 83,
#  261: 84,
#  258: 85,
#  259: 86,
# ...

# %%
with open('sort_info_old_new_map.json', 'w') as f:
    json.dump(tgt_map, f)

# %%
with open('sort_info_old_new_map.json') as f:
    sion_map = json.load(f)

# %%
sion_map
# Out:
# {'2': 0,
#  '4': 1,
#  '8': 2,
#  '12': 3,
#  '13': 4,
#  '17': 5,
#  '15': 6,
#  '19': 7,
#  '18': 8,
#  '20': 9,
#  '23': 10,
#  '29': 11,
#  '37': 12,
#  '49': 13,
#  '44': 14,
#  '38': 15,
#  '48': 16,
#  '51': 17,
#  '54': 18,
#  '53': 19,
#  '58': 20,
#  '63': 21,
#  '55': 22,
#  '56': 23,
#  '71': 24,
#  '73': 25,
#  '77': 26,
#  '84': 27,
#  '90': 28,
#  '87': 29,
#  '93': 30,
#  '94': 31,
#  '99': 32,
#  '100': 33,
#  '102': 34,
#  '114': 35,
#  '117': 36,
#  '128': 37,
#  '126': 38,
#  '130': 39,
#  '125': 40,
#  '124': 41,
#  '129': 42,
#  '139': 43,
#  '135': 44,
#  '132': 45,
#  '136': 46,
#  '140': 47,
#  '142': 48,
#  '143': 49,
#  '148': 50,
#  '152': 51,
#  '151': 52,
#  '159': 53,
#  '160': 54,
#  '163': 55,
#  '172': 56,
#  '170': 57,
#  '166': 58,
#  '186': 59,
#  '187': 60,
#  '193': 61,
#  '190': 62,
#  '198': 63,
#  '203': 64,
#  '208': 65,
#  '204': 66,
#  '206': 67,
#  '219': 68,
#  '234': 69,
#  '230': 70,
#  '228': 71,
#  '233': 72,
#  '227': 73,
# ...
